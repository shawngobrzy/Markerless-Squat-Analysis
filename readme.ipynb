# %% [markdown]
# Can pose-derived biomechanical features distinguish symmetrical from intentionally asymmetrical squat patterns?

# %% [markdown]
# Can markerless pose-derived kinematic features characterize differences in squat movement patterns?

# %% [markdown]
# Which biomechanical features are actually driving the model's classification of symmetrical vs. intentional-asymmetry squats?

# %% [markdown]
# To reduce subject-specific data leakage, cross-validation was performed using participant-level grouping rather than randomly splitting individual movement samples.

# %% [markdown]
# Mediapipe's wordlandmarks will be used to provide information that helps define
#
# hip flexion
# knee flexion
# ankle angle
# trunk angle
# ROM
# movement velocity

# %% [markdown]
# Accuracy: Overall percentage classified correctly.
# Precision: When the model predicts asymmetrical, how often is it correct?
# Recall: Of the actual asymmetrical squats, how many did it identify?
# F1: Balance between precision and recall.

# %% [markdown]
# Why did the model classify this squat as asymmetric: SHAP

# %% [markdown]
# ![image.png](attachment:image.png)
